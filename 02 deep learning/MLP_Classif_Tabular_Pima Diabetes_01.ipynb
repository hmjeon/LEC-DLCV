# %% [markdown]
# # **MLP - Pima Diabets**
#
# **Context**
#
# This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases. The objective of the dataset is to diagnostically predict whether or not a patient has diabetes, based on certain diagnostic measurements included in the dataset. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients here are females at least 21 years old of Pima Indian heritage.
#
# **Content**
#
# The datasets consists of several medical predictor variables and one target variable, Outcome. Predictor variables includes the number of pregnancies the patient has had, their BMI, insulin level, age, and so on.
#
# **Acknowledgements**
#
# Smith, J.W., Everhart, J.E., Dickson, W.C., Knowler, W.C., & Johannes, R.S. (1988). Using the ADAP learning algorithm to forecast the onset of diabetes mellitus. In Proceedings of the Symposium on Computer Applications and Medical Care (pp. 261--265). IEEE Computer Society Press.
#
# **Inspiration**
#
# Can you build a machine learning model to accurately predict whether or not the patients in the dataset have diabetes or not?

# %%
# Google drive mount
from google.colab import drive
drive.mount('/content/drive')

# Set my working directory
import os
os.chdir("/content/drive/MyDrive/Deep Learning/02 MLP")
os.getcwd()
# Out:
# Mounted at /content/drive
# '/content/drive/MyDrive/Deep Learning/02 MLP'

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# load the dataset, split into input (X) and output (y) variables
dataset = np.loadtxt('../dataset/dataset_diabetes.csv', skiprows=1, delimiter=',')
X = dataset[:,0:8]
y = dataset[:,8]

X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# define the model
model = nn.Sequential(
    nn.Linear(8, 12),
    nn.ReLU(),
    nn.Linear(12, 8),
    nn.ReLU(),
    nn.Linear(8, 1),
    nn.Sigmoid()
)
print(model)

# train the model
loss_fn   = nn.BCELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.001)

n_epochs = 100
batch_size = 10

for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')

# compute accuracy (no_grad is optional)
with torch.no_grad():
    y_pred = model(X)
accuracy = (y_pred.round() == y).float().mean()
print(f"Accuracy {accuracy}")
# Out:
# Sequential(
#   (0): Linear(in_features=8, out_features=12, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=12, out_features=8, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=8, out_features=1, bias=True)
#   (5): Sigmoid()
# )
# Finished epoch 0, latest loss 0.6705176830291748
# Finished epoch 1, latest loss 0.624144434928894
# Finished epoch 2, latest loss 0.6597209572792053
# Finished epoch 3, latest loss 0.5886387228965759
# Finished epoch 4, latest loss 0.5743430256843567
# Finished epoch 5, latest loss 0.5605312585830688
# Finished epoch 6, latest loss 0.543185830116272
# Finished epoch 7, latest loss 0.5287259221076965
# Finished epoch 8, latest loss 0.5269332528114319
# Finished epoch 9, latest loss 0.5021027326583862
# Finished epoch 10, latest loss 0.4929580092430115
# Finished epoch 11, latest loss 0.4841318130493164
# Finished epoch 12, latest loss 0.46976861357688904
# Finished epoch 13, latest loss 0.45779111981391907
# Finished epoch 14, latest loss 0.44852250814437866
# Finished epoch 15, latest loss 0.4441654682159424
# Finished epoch 16, latest loss 0.4353538155555725
# Finished epoch 17, latest loss 0.41807106137275696
# Finished epoch 18, latest loss 0.4256630539894104
# Finished epoch 19, latest loss 0.4192143678665161
# Finished epoch 20, latest loss 0.4179375469684601
# Finished epoch 21, latest loss 0.41855260729789734
# Finished epoch 22, latest loss 0.4193863868713379
# Finished epoch 23, latest loss 0.4175126254558563
# Finished epoch 24, latest loss 0.41581687331199646
# Finished epoch 25, latest loss 0.4158656895160675
# Finished epoch 26, latest loss 0.413208931684494
# Finished epoch 27, latest loss 0.41279137134552
# Finished epoch 28, latest loss 0.4038270115852356
# Finished epoch 29, latest loss 0.40239417552948
# Finished epoch 30, latest loss 0.39989638328552246
# Finished epoch 31, latest loss 0.39712539315223694
# Finished epoch 32, latest loss 0.39793628454208374
# Finished epoch 33, latest loss 0.39417317509651184
# Finished epoch 34, latest loss 0.3907695412635803
# Finished epoch 35, latest loss 0.3892548084259033
# Finished epoch 36, latest loss 0.3842398226261139
# Finished epoch 37, latest loss 0.3845982551574707
# Finished epoch 38, latest loss 0.37681102752685547
# Finished epoch 39, latest loss 0.3760118782520294
# Finished epoch 40, latest loss 0.37760767340660095
# Finished epoch 41, latest loss 0.37660911679267883
# Finished epoch 42, latest loss 0.37543079257011414
# Finished epoch 43, latest loss 0.3726537525653839
# Finished epoch 44, latest loss 0.3684157729148865
# Finished epoch 45, latest loss 0.36846795678138733
# Finished epoch 46, latest loss 0.3638574182987213
# Finished epoch 47, latest loss 0.3690994381904602
# Finished epoch 48, latest loss 0.36847639083862305
# Finished epoch 49, latest loss 0.3708600103855133
# Finished epoch 50, latest loss 0.36381348967552185
# Finished epoch 51, latest loss 0.3648994565010071
# Finished epoch 52, latest loss 0.3575000464916229
# Finished epoch 53, latest loss 0.361354261636734
# Finished epoch 54, latest loss 0.36205118894577026
# Finished epoch 55, latest loss 0.3563876748085022
# Finished epoch 56, latest loss 0.35936668515205383
# Finished epoch 57, latest loss 0.3558464050292969
# Finished epoch 58, latest loss 0.35217082500457764
# Finished epoch 59, latest loss 0.3515770137310028
# Finished epoch 60, latest loss 0.35242220759391785
# Finished epoch 61, latest loss 0.3511137366294861
# Finished epoch 62, latest loss 0.34735938906669617
# Finished epoch 63, latest loss 0.3479602038860321
# Finished epoch 64, latest loss 0.34824132919311523
# Finished epoch 65, latest loss 0.34777912497520447
# Finished epoch 66, latest loss 0.3468881845474243
# Finished epoch 67, latest loss 0.34745630621910095
# Finished epoch 68, latest loss 0.34974774718284607
# Finished epoch 69, latest loss 0.346921443939209
# Finished epoch 70, latest loss 0.34543704986572266
# Finished epoch 71, latest loss 0.34686723351478577
# Finished epoch 72, latest loss 0.34441474080085754
# Finished epoch 73, latest loss 0.34563347697257996
# Finished epoch 74, latest loss 0.3399239480495453
# Finished epoch 75, latest loss 0.341513067483902
# Finished epoch 76, latest loss 0.3410406708717346
# Finished epoch 77, latest loss 0.3387361168861389
# Finished epoch 78, latest loss 0.3392220735549927
# Finished epoch 79, latest loss 0.34545597434043884
# Finished epoch 80, latest loss 0.34081536531448364
# Finished epoch 81, latest loss 0.34090226888656616
# Finished epoch 82, latest loss 0.3401291072368622
# Finished epoch 83, latest loss 0.3439396321773529
# Finished epoch 84, latest loss 0.34243810176849365
# Finished epoch 85, latest loss 0.34225088357925415
# Finished epoch 86, latest loss 0.34097033739089966
# Finished epoch 87, latest loss 0.33934473991394043
# Finished epoch 88, latest loss 0.3426264524459839
# Finished epoch 89, latest loss 0.3404074013233185
# Finished epoch 90, latest loss 0.33932459354400635
# Finished epoch 91, latest loss 0.3395468294620514
# Finished epoch 92, latest loss 0.3399372398853302
# Finished epoch 93, latest loss 0.3410131335258484
# Finished epoch 94, latest loss 0.3387255072593689
# Finished epoch 95, latest loss 0.3385801613330841
# Finished epoch 96, latest loss 0.3410719931125641
# Finished epoch 97, latest loss 0.33796006441116333
# Finished epoch 98, latest loss 0.3383682668209076
# Finished epoch 99, latest loss 0.3374592661857605
# Accuracy 0.7890625
