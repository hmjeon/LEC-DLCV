# %% [markdown]
# ### **01. 변수 및 데이터구조**

# %% [markdown]
# #### **기본 데이터 타입**

# %%
a = 10        # 정수형(integer) 변수 a 선언
b = 11.4      # 실수형(float) 변수 b 선언

# 변수 출력
print(a)
print(b)
print(a, b)
# Out:
# 10
# 11.4
# 10 11.4

# %% [markdown]
# #### **주석**
#
# - 코랩에서 일정 라인에 대한 주석처리: ctrl + /
# - 여러 줄에 대한 주석처리: ''' ... ''' 또는 """ ... """

# %%
# This is the comment line
a = 10
b = 11.4

# %% [markdown]
# #### **print 함수**

# %%
print(a, b)
print(a, 10, 200, b)
# Out:
# 10 11.4
# 10 10 200 11.4

# %% [markdown]
# #### **print함수 설정**
# - sep : 구분자, 각 출력할 변수 사이에서 구별하는 역할
# - end : 마지막에 출력할 문자열

# %%
print(a, b, 10, 100, 'abc', sep='*', end='!!')
# Out:
# 10*11.4*10*100*abc!!

# %% [markdown]
# #### **변수이름**
# - 숫자로 시작하면 안됨
# - 대소문자 구별

# %%
abcABC = 100
_abc124 = 200
ABC124 = 200
a456BC = 100

a = 200
number_of_students = 200

# %% [markdown]
# #### **reserved keywords (예약어)**
# - python에서 미리 정해 둔 키워드
# - 변수, 함수, 모듈, 클래스 등의 이름으로 사용불가

# %%
'''
for
while 
if
elif 
else 
class
try
except
class
'''

_class = 100
print(_class)
# Out:
# 100

# %% [markdown]
# #### **기본 데이터 타입**
# - 정수(integer), 실수(float), 문자열(string), 불리언(boolean)
# - type 함수: 변수의 타입을 반환
# - None: 변수 선언시 아무런 값을 가지지 않을때 사용

# %%
a = 10
b = 11.45
print(type(a))
print(type(b))

c = None
print(c)
# Out:
# <class 'int'>
# <class 'float'>
# None

# %% [markdown]
# #### **비교연산자**
# - 연산자: 비교연산자, 논리연산자
# - 이들의 결과는 bool 타입

# %%
a = 5
b = 4

print(a > b)  # True
print(a < b)  # False
print(a >= b) # True
print(a <= b) # False
print(a == b) # False
print(a != b) # True

c = a > b
c = True
print(type(c))
print(c)
# Out:
# True
# False
# True
# False
# False
# True
# <class 'bool'>
# True

# %% [markdown]
# #### **숫자형 데이터 타입**
# - 정수 및 실수를 활용하여, 기본 사칙연산 가능

# %%
a = 7
b = 4

print('a + b = ', a + b)
print('a * b = ', a * b)
print('a - b = ', a - b)
print('a / b = ', a / b)
print('a // b = ', a // b)
print('a % b = ', a % b)
print('a ** b = ', a ** b)
# Out:
# a + b =  11
# a * b =  28
# a - b =  3
# a / b =  1.75
# a // b =  1
# a % b =  3
# a ** b =  2401

# %% [markdown]
# #### **연산자 우선순위**

# %%
a = 5
b = 4

print(a + b * 4)
print((a + b) * 4)
# Out:
# 21
# 36

# %% [markdown]
# #### **변수 값 변경**

# %%
a = 9
t = a - 3
a = t
print(a)

a = 9
a = a - 3
print(a)

a = 9
a -= 3
print(a)

a = 9
a **= 3
print(a)
# Out:
# 6
# 6
# 6
# 729
